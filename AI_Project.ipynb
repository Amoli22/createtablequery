# %% [markdown]
# <a href="https://colab.research.google.com/github/Amoli22/createtablequery/blob/main/AI_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the CSV file (this will work in Google Colab)
file_path = '/content/tips.csv'  # or '/mnt/data/tips.csv' if you're not using Colab upload
df = pd.read_csv(file_path)

# Show first 5 rows of the dataset
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Group by gender and calculate mean tips
gender_tip = df.groupby('sex')['tip'].mean().reset_index()

# Plot
plt.figure(figsize=(6,4))
sns.barplot(data=gender_tip, x='sex', y='tip', palette='pastel')
plt.title('Average Tip by Gender')
plt.ylabel('Average Tip')
plt.show()
# Out:
# <ipython-input-8-331a5241441a>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=gender_tip, x='sex', y='tip', palette='pastel')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: This makes plots look better
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['tip'], kde=True, bins=20)
plt.title('Distribution of Tip Amounts')
plt.xlabel('Tip')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram of tip amounts
plt.figure(figsize=(8,5))
sns.histplot(df['tip'], kde=True, bins=20)
plt.title('Distribution of Tip Amounts')
plt.xlabel('Tip')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1df1445ba0b1> in <cell line: 0>()
#       1 # Histogram of tip amounts
# ----> 2 plt.figure(figsize=(8,5))
#       3 sns.histplot(df['tip'], kde=True, bins=20)
#       4 plt.title('Distribution of Tip Amounts')
#       5 plt.xlabel('Tip')
#
# NameError: name 'plt' is not defined

# %%
# Look at unique values for each categorical column
print("Sex:", df['sex'].unique())
print("Smoker:", df['smoker'].unique())
print("Day:", df['day'].unique())
print("Time:", df['time'].unique())
# Out:
# Sex: ['Female' 'Male']
# Smoker: ['No' 'Yes']
# Day: ['Sun' 'Sat' 'Thur' 'Fri']
# Time: ['Dinner' 'Lunch']

# %%
# Check data types and missing values
df.info()

# Get basic statistics
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000
